# %% [markdown]
# # Nettoyage et exploration de données

# %% [markdown]
# ## 1. Importation des données

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel(r"C:\Users\user\Downloads\Flight_Price_resources2\Data.xlsx")

# %%
data.head(4)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218

# %%
data.tail(4)
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10679              CCU → BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20        11:20       3h    non-stop
# 10681              BLR → DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753

# %% [markdown]
# ## 2. Traitement des valeurs manquantes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
data[data['Total_Stops'].isnull()]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 9039  09:25 07 May  23h 40m         NaN         No info   7480

# %% [markdown]
# #### Comme on a 2 seulement deux valeurs manquantes on peut directement les supprimer

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
data.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %% [markdown]
# ## 3. Traitement des valeurs aberrantes
# ### On va traiter les valeurs aberrantes après la visualisation des données pour mieux comprendre les relations et capturer les dépendances entre les variables

# %% [markdown]
# ## 4. Data Pre-processing et extraction de day, month et year de la colonne "Date_of_Journey"

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
data.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662

# %%
data.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
def change_into_Datetime(col):
    data[col] = pd.to_datetime(data[col])

# %%
import warnings 
from warnings import filterwarnings
filterwarnings("ignore")

# %%
for feature in ['Dep_Time', 'Arrival_Time' , 'Date_of_Journey']:
    change_into_Datetime(feature)

# %%
data.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time           datetime64[ns]
# Arrival_Time       datetime64[ns]
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Price                       int64
# dtype: object

# %%
data["Journey_day"] = data['Date_of_Journey'].dt.day

# %%
data["Journey_month"] = data['Date_of_Journey'].dt.month

# %%
data["Journey_year"] = data['Date_of_Journey'].dt.year

# %%
data.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2025-06-23 22:20:00 2025-03-22 01:10:00   2h 50m    non-stop
# 1 2025-06-23 05:50:00 2025-06-23 13:15:00   7h 25m     2 stops
# 2 2025-06-23 09:25:00 2025-06-10 04:25:00      19h     2 stops
#
#   Additional_Info  Price  Journey_day  Journey_month  Journey_year
# 0         No info   3897           24              3          2019
# 1         No info   7662            1              5          2019
# 2         No info  13882            9              6          2019

# %% [markdown]
# ## 5. Nettoyage des colonnes Dep_Time & Arrival_Time

# %%
def extract_hour_min(df , col):
    df[col+"_hour"] = df[col].dt.hour
    df[col+"_minute"] = df[col].dt.minute
    return df.head(3)

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price', 'Journey_day', 'Journey_month',
#        'Journey_year'],
#       dtype='object')

# %%
extract_hour_min(data , "Dep_Time")
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2025-06-23 22:20:00 2025-03-22 01:10:00   2h 50m    non-stop
# 1 2025-06-23 05:50:00 2025-06-23 13:15:00   7h 25m     2 stops
# 2 2025-06-23 09:25:00 2025-06-10 04:25:00      19h     2 stops
#
#   Additional_Info  Price  Journey_day  Journey_month  Journey_year  \
# 0         No info   3897           24              3          2019
# 1         No info   7662            1              5          2019
# 2         No info  13882            9              6          2019
#
#    Dep_Time_hour  Dep_Time_minute
# 0             22               20
# 1              5               50
# ...

# %%
extract_hour_min(data , "Arrival_Time")
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2025-06-23 22:20:00 2025-03-22 01:10:00   2h 50m    non-stop
# 1 2025-06-23 05:50:00 2025-06-23 13:15:00   7h 25m     2 stops
# 2 2025-06-23 09:25:00 2025-06-10 04:25:00      19h     2 stops
#
#   Additional_Info  Price  Journey_day  Journey_month  Journey_year  \
# 0         No info   3897           24              3          2019
# 1         No info   7662            1              5          2019
# 2         No info  13882            9              6          2019
#
#    Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  Arrival_Time_minute
# ...

# %%
cols_to_drop = ['Arrival_Time' , "Dep_Time"]

data.drop(cols_to_drop , axis=1 , inplace=True )

# %%
data.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Duration Total_Stops Additional_Info  Price  Journey_day  Journey_month  \
# 0   2h 50m    non-stop         No info   3897           24              3
# 1   7h 25m     2 stops         No info   7662            1              5
# 2      19h     2 stops         No info  13882            9              6
#
#    Journey_year  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# 0          2019             22               20                  1
# 1          2019              5               50                 13
# 2          2019              9               25                  4
#
#    Arrival_Time_minute
# 0                   10
# 1                   15
# ...

# %%
data.shape
# Out:
# (10682, 16)

# %% [markdown]
# ## 6. Prétraitement de la colonne "Duration"

# %%
def preprocess_duration(x):
    if 'h' not in x:
        x = '0h' + ' ' + x
    elif 'm' not in x:
        x = x + ' ' +'0m'
        
    return x

# %%
data['Duration'] = data['Duration'].apply(preprocess_duration)

# %%
data['Duration']
# Out:
# 0        2h 50m
# 1        7h 25m
# 2        19h 0m
# 3        5h 25m
# 4        4h 45m
#           ...
# 10678    2h 30m
# 10679    2h 35m
# 10680     3h 0m
# 10681    2h 40m
# 10682    8h 20m
# Name: Duration, Length: 10682, dtype: object

# %%
data['Duration_hours'] = data['Duration'].apply(lambda x : int(x.split(' ')[0][0:-1]))

# %%
data['Duration_mins'] = data['Duration'].apply(lambda x : int(x.split(' ')[1][0:-1]))

# %%
data.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1  Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Duration Total_Stops Additional_Info  Price  Journey_day  Journey_month  \
# 0   2h 50m    non-stop         No info   3897           24              3
# 1   7h 25m     2 stops         No info   7662            1              5
#
#    Journey_year  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# 0          2019             22               20                  1
# 1          2019              5               50                 13
#
#    Arrival_Time_minute  Duration_hours  Duration_mins
# 0                   10               2             50
# 1                   15               7             25

# %% [markdown]
# # Data visualisation

# %% [markdown]
# ## 1. Analyse des départs des vols

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Duration', 'Total_Stops', 'Additional_Info', 'Price', 'Journey_day',
#        'Journey_month', 'Journey_year', 'Dep_Time_hour', 'Dep_Time_minute',
#        'Arrival_Time_hour', 'Arrival_Time_minute', 'Duration_hours',
#        'Duration_mins'],
#       dtype='object')

# %%
def flight_dep_time(x):
    
    
    if (x>4) and (x<=8):
        return "Early Morning"
    
    elif (x>8) and (x<=12):
        return "Morning"
    
    elif (x>12) and (x<=16):
        return "Noon"
    
    elif (x>16) and (x<=20):
        return "Evening"
    
    elif (x>20) and (x<=24):
        return "Night"
    
    else:
        return "late night"

# %%
import plotly
import cufflinks as cf
from cufflinks.offline import go_offline
from plotly.offline import plot , iplot , init_notebook_mode , download_plotlyjs
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
data['Dep_Time_hour'].apply(flight_dep_time).value_counts().iplot(kind="bar")

# %% [markdown]
# ## 2. Analyse de la relation entre Duration et Price

# %%
data['Duration']
# Out:
# 0        2h 50m
# 1        7h 25m
# 2        19h 0m
# 3        5h 25m
# 4        4h 45m
#           ...
# 10678    2h 30m
# 10679    2h 35m
# 10680     3h 0m
# 10681    2h 40m
# 10682    8h 20m
# Name: Duration, Length: 10682, dtype: object

# %%
data['Duration_total_mins'] = data['Duration'].str.replace('h' ,"*60").str.replace(' ' , '+').str.replace('m' , "*1").apply(eval)

# %%
data['Duration_total_mins']
# Out:
# 0         170
# 1         445
# 2        1140
# 3         325
# 4         285
#          ...
# 10678     150
# 10679     155
# 10680     180
# 10681     160
# 10682     500
# Name: Duration_total_mins, Length: 10682, dtype: int64

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Duration', 'Total_Stops', 'Additional_Info', 'Price', 'Journey_day',
#        'Journey_month', 'Journey_year', 'Dep_Time_hour', 'Dep_Time_minute',
#        'Arrival_Time_hour', 'Arrival_Time_minute', 'Duration_hours',
#        'Duration_mins', 'Duration_total_mins'],
#       dtype='object')

# %%
sns.scatterplot(x="Duration_total_mins" , y="Price" , data=data)
# Out:
# <Axes: xlabel='Duration_total_mins', ylabel='Price'>

# %%
sns.lmplot(x="Duration_total_mins" , y="Price" , data=data)

# %% [markdown]
# ## 3. Analyse de la relation entre total stops et price

# %%
sns.scatterplot(x="Duration_total_mins" , y="Price" , hue="Total_Stops", data=data)
# Out:
# <Axes: xlabel='Duration_total_mins', ylabel='Price'>

# %% [markdown]
# ### 4. Analyse de la relation entre Airline et Price

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Duration', 'Total_Stops', 'Additional_Info', 'Price', 'Journey_day',
#        'Journey_month', 'Journey_year', 'Dep_Time_hour', 'Dep_Time_minute',
#        'Arrival_Time_hour', 'Arrival_Time_minute', 'Duration_hours',
#        'Duration_mins', 'Duration_total_mins'],
#       dtype='object')

# %%
sns.boxplot(y='Price' , x='Airline' , data=data.sort_values('Price' , ascending=False))
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# ## 5. Traitement des valeurs aberrantes

# %%
def plot(df, col):
    fig , (ax1 , ax2 , ax3) = plt.subplots(3,1)
    
    sns.distplot(df[col] , ax=ax1)
    sns.boxplot(df[col] , ax=ax2)
    sns.distplot(df[col] , ax=ax3 , kde=False)

# %%
plot(data , 'Price')

# %%
q1 = data['Price'].quantile(0.25)
q3 = data['Price'].quantile(0.75)

iqr = q3- q1

maximum = q3 + 1.5*iqr
minimum = q1 - 1.5*iqr

# %%
print(maximum)
# Out:
# 23017.0

# %%
print(minimum)
# Out:
# -5367.0

# %%
print([price for price in data['Price'] if price> maximum or price<minimum])
# Out:
# [27430, 36983, 26890, 26890, 25139, 27210, 52229, 26743, 26890, 25735, 27992, 26890, 26890, 23583, 26890, 23533, 24115, 25735, 54826, 31783, 27992, 26890, 26890, 25430, 36235, 27210, 26890, 25735, 54826, 26890, 35185, 79512, 28097, 27992, 26890, 25735, 26092, 31825, 25913, 25735, 27992, 31825, 23267, 62427, 54826, 31825, 25430, 26890, 36235, 23843, 26890, 25735, 28322, 25735, 25735, 31825, 26890, 27992, 34273, 46490, 29528, 26890, 26890, 26890, 34503, 26890, 27992, 26890, 26890, 23170, 24528, 26890, 27992, 25735, 34608, 25703, 26890, 23528, 31825, 27282, 25735, 27992, 52285, 24017, 31945, 26890, 24318, 23677, 27992, 24210, 57209, 26890, 31825, 26480]

# %%
len([price for price in data['Price'] if price> maximum or price<minimum])
# Out:
# 94

# %%
data['Price'] = np.where(data['Price']>=35000 , data['Price'].median() , data['Price'])

# %%
plot(data , 'Price')

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ## 1. Application de One hot encoding pour la variable Source

# %%
data.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1  Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Duration Total_Stops Additional_Info   Price  Journey_day  Journey_month  \
# 0   2h 50m    non-stop         No info  3897.0           24              3
# 1   7h 25m     2 stops         No info  7662.0            1              5
#
#    Journey_year  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# 0          2019             22               20                  1
# 1          2019              5               50                 13
#
#    Arrival_Time_minute  Duration_hours  Duration_mins  Duration_total_mins
# 0                   10               2             50                  170
# 1                   15               7             25                  445

# %%
cat_col = [col for col in data.columns if data[col].dtype=="object"]

# %%
num_col = [col for col in data.columns if data[col].dtype!="object"]

# %%
cat_col
# Out:
# ['Airline',
#  'Source',
#  'Destination',
#  'Route',
#  'Duration',
#  'Total_Stops',
#  'Additional_Info']

# %%
data['Source'].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
data['Source'].apply(lambda x : 1 if x=='Banglore' else 0)
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 10678    0
# 10679    0
# 10680    1
# 10681    1
# 10682    0
# Name: Source, Length: 10682, dtype: int64

# %%
for sub_category in data['Source'].unique():
    data['Source_'+sub_category] = data['Source'].apply(lambda x : 1 if x==sub_category else 0)

# %%
data.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Duration Total_Stops Additional_Info    Price  Journey_day  ...  \
# 0   2h 50m    non-stop         No info   3897.0           24  ...
# 1   7h 25m     2 stops         No info   7662.0            1  ...
# 2   19h 0m     2 stops         No info  13882.0            9  ...
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hours  Duration_mins  \
# 0                  1                   10               2             50
# 1                 13                   15               7             25
# 2                  4                   25              19              0
#
#    Duration_total_mins  Source_Banglore  Source_Kolkata  Source_Delhi  \
# ...

# %% [markdown]
# ## 2. Application de target guided Ordinal encoding pour Airline et Destination

# %%
cat_col
# Out:
# ['Airline',
#  'Source',
#  'Destination',
#  'Route',
#  'Duration',
#  'Total_Stops',
#  'Additional_Info']

# %%
data.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1  Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Duration Total_Stops Additional_Info   Price  Journey_day  ...  \
# 0   2h 50m    non-stop         No info  3897.0           24  ...
# 1   7h 25m     2 stops         No info  7662.0            1  ...
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hours  Duration_mins  \
# 0                  1                   10               2             50
# 1                 13                   15               7             25
#
#    Duration_total_mins  Source_Banglore  Source_Kolkata  Source_Delhi  \
# 0                  170                1               0             0
# 1                  445                0               1             0
#
#    Source_Chennai  Source_Mumbai
# 0               0              0
# 1               0              0
#
# ...

# %%
data['Airline'].nunique()
# Out:
# 12

# %%
data.groupby(['Airline'])['Price'].mean().sort_values()
# Out:
# Airline
# Trujet                                4140.000000
# SpiceJet                              4338.284841
# Air Asia                              5590.260188
# IndiGo                                5673.682903
# GoAir                                 5861.056701
# Vistara                               7796.348643
# Jet Airways Business                  8372.000000
# Vistara Premium economy               8962.333333
# Air India                             9612.427756
# Multiple carriers                    10878.755853
# Multiple carriers Premium economy    11418.846154
# Jet Airways                          11586.271759
# Name: Price, dtype: float64

# %%
airlines = data.groupby(['Airline'])['Price'].mean().sort_values().index

# %%
airlines
# Out:
# Index(['Trujet', 'SpiceJet', 'Air Asia', 'IndiGo', 'GoAir', 'Vistara',
#        'Jet Airways Business', 'Vistara Premium economy', 'Air India',
#        'Multiple carriers', 'Multiple carriers Premium economy',
#        'Jet Airways'],
#       dtype='object', name='Airline')

# %%
dict_airlines = {key:index for index , key in enumerate(airlines , 0)}

# %%
dict_airlines
# Out:
# {'Trujet': 0,
#  'SpiceJet': 1,
#  'Air Asia': 2,
#  'IndiGo': 3,
#  'GoAir': 4,
#  'Vistara': 5,
#  'Jet Airways Business': 6,
#  'Vistara Premium economy': 7,
#  'Air India': 8,
#  'Multiple carriers': 9,
#  'Multiple carriers Premium economy': 10,
#  'Jet Airways': 11}

# %%
data['Airline'] = data['Airline'].map(dict_airlines)

# %%
data['Airline']
# Out:
# 0         3
# 1         8
# 2        11
# 3         3
# 4         3
#          ..
# 10678     2
# 10679     8
# 10680    11
# 10681     5
# 10682     8
# Name: Airline, Length: 10682, dtype: int64

# %%
data.head(3)
# Out:
#    Airline Date_of_Journey    Source Destination                  Route  \
# 0        3      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1        8      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2       11      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Duration Total_Stops Additional_Info    Price  Journey_day  ...  \
# 0   2h 50m    non-stop         No info   3897.0           24  ...
# 1   7h 25m     2 stops         No info   7662.0            1  ...
# 2   19h 0m     2 stops         No info  13882.0            9  ...
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hours  Duration_mins  \
# 0                  1                   10               2             50
# 1                 13                   15               7             25
# 2                  4                   25              19              0
#
#    Duration_total_mins  Source_Banglore  Source_Kolkata  Source_Delhi  \
# ...

# %%
data['Destination'].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
data['Destination'].replace('New Delhi' , 'Delhi' , inplace=True)

# %%
data['Destination'].unique()
# Out:
# array(['Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Hyderabad'],
#       dtype=object)

# %%
dest = data.groupby(['Destination'])['Price'].mean().sort_values().index

# %%
dest
# Out:
# Index(['Kolkata', 'Hyderabad', 'Delhi', 'Banglore', 'Cochin'], dtype='object', name='Destination')

# %%
dict_dest = {key:index for index , key in enumerate(dest , 0)}

# %%
dict_dest
# Out:
# {'Kolkata': 0, 'Hyderabad': 1, 'Delhi': 2, 'Banglore': 3, 'Cochin': 4}

# %%
data['Destination'] = data['Destination'].map(dict_dest)

# %%
data['Destination']
# Out:
# 0        2
# 1        3
# 2        4
# 3        3
# 4        2
#         ..
# 10678    3
# 10679    3
# 10680    2
# 10681    2
# 10682    4
# Name: Destination, Length: 10682, dtype: int64

# %%
data.head(3)
# Out:
#    Airline Date_of_Journey    Source  Destination                  Route  \
# 0        3      2019-03-24  Banglore            2              BLR → DEL
# 1        8      2019-05-01   Kolkata            3  CCU → IXR → BBI → BLR
# 2       11      2019-06-09     Delhi            4  DEL → LKO → BOM → COK
#
#   Duration Total_Stops Additional_Info    Price  Journey_day  ...  \
# 0   2h 50m    non-stop         No info   3897.0           24  ...
# 1   7h 25m     2 stops         No info   7662.0            1  ...
# 2   19h 0m     2 stops         No info  13882.0            9  ...
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hours  Duration_mins  \
# 0                  1                   10               2             50
# 1                 13                   15               7             25
# 2                  4                   25              19              0
#
#    Duration_total_mins  Source_Banglore  Source_Kolkata  Source_Delhi  \
# ...

# %% [markdown]
# ## 3. Application de  Label Encoding sur Total stops

# %%
data.head(3)
# Out:
#    Airline Date_of_Journey    Source  Destination                  Route  \
# 0        3      2019-03-24  Banglore            2              BLR → DEL
# 1        8      2019-05-01   Kolkata            3  CCU → IXR → BBI → BLR
# 2       11      2019-06-09     Delhi            4  DEL → LKO → BOM → COK
#
#   Duration Total_Stops Additional_Info    Price  Journey_day  ...  \
# 0   2h 50m    non-stop         No info   3897.0           24  ...
# 1   7h 25m     2 stops         No info   7662.0            1  ...
# 2   19h 0m     2 stops         No info  13882.0            9  ...
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hours  Duration_mins  \
# 0                  1                   10               2             50
# 1                 13                   15               7             25
# 2                  4                   25              19              0
#
#    Duration_total_mins  Source_Banglore  Source_Kolkata  Source_Delhi  \
# ...

# %%
data['Total_Stops']
# Out:
# 0        non-stop
# 1         2 stops
# 2         2 stops
# 3          1 stop
# 4          1 stop
#            ...
# 10678    non-stop
# 10679    non-stop
# 10680    non-stop
# 10681    non-stop
# 10682     2 stops
# Name: Total_Stops, Length: 10682, dtype: object

# %%
data['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
stop = {'non-stop':0, '2 stops':2, '1 stop':1, '3 stops':3, '4 stops':4}

# %%
data['Total_Stops'] = data['Total_Stops'].map(stop)

# %%
data['Total_Stops']
# Out:
# 0        0
# 1        2
# 2        2
# 3        1
# 4        1
#         ..
# 10678    0
# 10679    0
# 10680    0
# 10681    0
# 10682    2
# Name: Total_Stops, Length: 10682, dtype: int64

# %% [markdown]
# ### Suppression des features non nécessaires

# %%
data.head(1)
# Out:
#    Airline Date_of_Journey    Source  Destination      Route Duration  \
# 0        3      2019-03-24  Banglore            2  BLR → DEL   2h 50m
#
#    Total_Stops Additional_Info   Price  Journey_day  ...  Arrival_Time_hour  \
# 0            0         No info  3897.0           24  ...                  1
#
#    Arrival_Time_minute  Duration_hours  Duration_mins  Duration_total_mins  \
# 0                   10               2             50                  170
#
#    Source_Banglore  Source_Kolkata  Source_Delhi  Source_Chennai  \
# 0                1               0             0               0
#
#    Source_Mumbai
# 0              0
#
# [1 rows x 24 columns]

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Duration', 'Total_Stops', 'Additional_Info', 'Price', 'Journey_day',
#        'Journey_month', 'Journey_year', 'Dep_Time_hour', 'Dep_Time_minute',
#        'Arrival_Time_hour', 'Arrival_Time_minute', 'Duration_hours',
#        'Duration_mins', 'Duration_total_mins', 'Source_Banglore',
#        'Source_Kolkata', 'Source_Delhi', 'Source_Chennai', 'Source_Mumbai'],
#       dtype='object')

# %%
data['Additional_Info'].value_counts()/len(data)*100
# Out:
# Additional_Info
# No info                         78.112713
# In-flight meal not included     18.554578
# No check-in baggage included     2.995694
# 1 Long layover                   0.177869
# Change airports                  0.065531
# Business class                   0.037446
# No Info                          0.028085
# 1 Short layover                  0.009362
# Red-eye flight                   0.009362
# 2 Long layover                   0.009362
# Name: count, dtype: float64

# %%
data.head(4)
# Out:
#    Airline Date_of_Journey    Source  Destination                  Route  \
# 0        3      2019-03-24  Banglore            2              BLR → DEL
# 1        8      2019-05-01   Kolkata            3  CCU → IXR → BBI → BLR
# 2       11      2019-06-09     Delhi            4  DEL → LKO → BOM → COK
# 3        3      2019-05-12   Kolkata            3        CCU → NAG → BLR
#
#   Duration  Total_Stops Additional_Info    Price  Journey_day  ...  \
# 0   2h 50m            0         No info   3897.0           24  ...
# 1   7h 25m            2         No info   7662.0            1  ...
# 2   19h 0m            2         No info  13882.0            9  ...
# 3   5h 25m            1         No info   6218.0           12  ...
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hours  Duration_mins  \
# 0                  1                   10               2             50
# 1                 13                   15               7             25
# ...

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Duration', 'Total_Stops', 'Additional_Info', 'Price', 'Journey_day',
#        'Journey_month', 'Journey_year', 'Dep_Time_hour', 'Dep_Time_minute',
#        'Arrival_Time_hour', 'Arrival_Time_minute', 'Duration_hours',
#        'Duration_mins', 'Duration_total_mins', 'Source_Banglore',
#        'Source_Kolkata', 'Source_Delhi', 'Source_Chennai', 'Source_Mumbai'],
#       dtype='object')

# %%
data['Journey_year'].unique()
# Out:
# array([2019])

# %%
data.drop(columns=['Date_of_Journey' , 'Additional_Info' , 'Duration_total_mins' , 'Source' , 'Journey_year'] , axis=1 , inplace=True)

# %%
data.columns
# Out:
# Index(['Airline', 'Destination', 'Route', 'Duration', 'Total_Stops', 'Price',
#        'Journey_day', 'Journey_month', 'Dep_Time_hour', 'Dep_Time_minute',
#        'Arrival_Time_hour', 'Arrival_Time_minute', 'Duration_hours',
#        'Duration_mins', 'Source_Banglore', 'Source_Kolkata', 'Source_Delhi',
#        'Source_Chennai', 'Source_Mumbai'],
#       dtype='object')

# %%
data.head(4)
# Out:
#    Airline  Destination                  Route Duration  Total_Stops    Price  \
# 0        3            2              BLR → DEL   2h 50m            0   3897.0
# 1        8            3  CCU → IXR → BBI → BLR   7h 25m            2   7662.0
# 2       11            4  DEL → LKO → BOM → COK   19h 0m            2  13882.0
# 3        3            3        CCU → NAG → BLR   5h 25m            1   6218.0
#
#    Journey_day  Journey_month  Dep_Time_hour  Dep_Time_minute  \
# 0           24              3             22               20
# 1            1              5              5               50
# 2            9              6              9               25
# 3           12              5             18                5
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hours  Duration_mins  \
# 0                  1                   10               2             50
# 1                 13                   15               7             25
# ...

# %%
data.drop(columns=['Route', 'Duration'] , axis=1 , inplace=True)

# %%
data.head(3)
# Out:
#    Airline  Destination  Total_Stops    Price  Journey_day  Journey_month  \
# 0        3            2            0   3897.0           24              3
# 1        8            3            2   7662.0            1              5
# 2       11            4            2  13882.0            9              6
#
#    Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  Arrival_Time_minute  \
# 0             22               20                  1                   10
# 1              5               50                 13                   15
# 2              9               25                  4                   25
#
#    Duration_hours  Duration_mins  Source_Banglore  Source_Kolkata  \
# 0               2             50                1               0
# 1               7             25                0               1
# 2              19              0                0               0
#
#    Source_Delhi  Source_Chennai  Source_Mumbai
# 0             0               0              0
# ...

# %% [markdown]
# ## 4. Sélection des variables

# %%
X = data.drop(['Price'] , axis=1)

# %%
y = data['Price']

# %%
from sklearn.feature_selection import mutual_info_regression

# %%
imp = mutual_info_regression(X , y)

# %%
imp
# Out:
# array([1.32431453, 1.07333384, 0.78583694, 0.37210707, 0.62221825,
#        0.9208998 , 0.75953962, 1.14147112, 0.90183871, 1.1221876 ,
#        0.67893711, 0.38904001, 0.46143812, 0.52212969, 0.13084348,
#        0.20028036])

# %%
imp_df = pd.DataFrame(imp , index=X.columns)

# %%
imp_df.columns = ['importance']

# %%
imp_df
# Out:
#                      importance
# Airline                1.324315
# Destination            1.073334
# Total_Stops            0.785837
# Journey_day            0.372107
# Journey_month          0.622218
# Dep_Time_hour          0.920900
# Dep_Time_minute        0.759540
# Arrival_Time_hour      1.141471
# Arrival_Time_minute    0.901839
# Duration_hours         1.122188
# Duration_mins          0.678937
# Source_Banglore        0.389040
# Source_Kolkata         0.461438
# Source_Delhi           0.522130
# Source_Chennai         0.130843
# Source_Mumbai          0.200280

# %%
imp_df.sort_values(by='importance' , ascending=False)
# Out:
#                      importance
# Airline                1.324315
# Arrival_Time_hour      1.141471
# Duration_hours         1.122188
# Destination            1.073334
# Dep_Time_hour          0.920900
# Arrival_Time_minute    0.901839
# Total_Stops            0.785837
# Dep_Time_minute        0.759540
# Duration_mins          0.678937
# Journey_month          0.622218
# Source_Delhi           0.522130
# Source_Kolkata         0.461438
# Source_Banglore        0.389040
# Journey_day            0.372107
# Source_Mumbai          0.200280
# Source_Chennai         0.130843

# %%
X.drop(columns=['Source_Mumbai', 'Source_Chennai'] , inplace=True)

# %% [markdown]
# ## 5. Construction des modèles

# %% [markdown]
# #### split dataset into train & test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
   X, y, test_size=0.25, random_state=42)

# %% [markdown]
# ### Modèle de régression linéaire

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

# Prédictions sur les données d'entraînement
y_train_pred = model.predict(X_train)
r2_train = r2_score(y_train, y_train_pred)

# Prédictions sur les données de test
y_test_pred = model.predict(X_test)
r2_test = r2_score(y_test, y_test_pred)

# métriques sur test
mae = mean_absolute_error(y_test, y_test_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Affichage
print("Résultat de la régression linéaire")
print(f"R² sur le train : {r2_train:.4f}")
print(f"R² sur le test  : {r2_test:.4f}")
print(f"MAE             : {mae:.2f}")
print(f"RMSE            : {rmse:.2f}")
# Out:
# Résultat de la régression linéaire
# R² sur le train : 0.5951
# R² sur le test  : 0.5686
# MAE             : 2021.98
# RMSE            : 2898.04

# %% [markdown]
# ### Modèle KNNs

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model = KNeighborsRegressor(n_neighbors=5)

# %%
model.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
# Prédictions sur les données d'entraînement
y_train_pred = model.predict(X_train)
r2_train = r2_score(y_train, y_train_pred)

# Prédictions sur les données de test
y_test_pred = model.predict(X_test)
r2_test = r2_score(y_test, y_test_pred)

# Autres métriques sur le test
mae = mean_absolute_error(y_test, y_test_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Affichage
print("Résultat du modèle KNNs")
print(f"R² (train) : {r2_train:.4f}")
print(f"R² (test)  : {r2_test:.4f}")
print(f"MAE        : {mae:.2f}")
print(f"RMSE       : {rmse:.2f}")
# Out:
# Résultat du modèle KNNs
# R² (train) : 0.7765
# R² (test)  : 0.6327
# MAE        : 1745.87
# RMSE       : 2673.97

# %% [markdown]
# ### Modèle de Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
ml_model = RandomForestRegressor()

# %%
ml_model.fit(X_train , y_train)
# Out:
# RandomForestRegressor()

# %%
# Prédictions
y_train_pred = ml_model.predict(X_train)
y_test_pred = ml_model.predict(X_test)

# Évaluation sur le train
r2_train = r2_score(y_train, y_train_pred)

# Évaluation sur le test
r2_test = r2_score(y_test, y_test_pred)
mae = mean_absolute_error(y_test, y_test_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Affichage des résultats
print("Résultat du modèle Random Forest")
print(f"R² sur le train : {r2_train:.4f}")
print(f"R² sur le test  : {r2_test:.4f}")
print(f"MAE sur le test : {mae:.2f}")
print(f"RMSE sur le test: {rmse:.2f}")
# Out:
# Résultat du modèle Random Forest
# R² sur le train : 0.9520
# R² sur le test  : 0.8154
# MAE sur le test : 1170.72
# RMSE sur le test: 1895.59

# %% [markdown]
# ## 16. Optimisation du modèle

# %%
param_dist = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10]
}

# %%
from sklearn.model_selection import RandomizedSearchCV

search = RandomizedSearchCV(ml_model, param_distributions=param_dist,
                            n_iter=10, cv=3, scoring='r2',
                            random_state=42, n_jobs=-1)

search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'max_depth': [None, 10, 20, 30],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300]},
#                    random_state=42, scoring='r2')

# %%
search.best_params_
# Out:
# {'n_estimators': 300, 'min_samples_split': 10, 'max_depth': None}

# %%
search.best_estimator_
# Out:
# RandomForestRegressor(min_samples_split=10, n_estimators=300)

# %%
search.best_score_
# Out:
# 0.8171419401880785

# %%
best_model = search.best_estimator_
y_pred = best_model.predict(X_test)

# Évaluation finale
print("R² sur les données de test :", r2_score(y_test, y_pred))
# Out:
# R² sur les données de test : 0.8337022324230574
